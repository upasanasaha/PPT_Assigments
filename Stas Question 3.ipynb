# %% [markdown]
# **Q-3. Consider the ‘Blood Pressure Before’ and ‘Blood Pressure After’ columns from the data and calculate the following
# https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_**
#
# **a. Measure the dispersion in both and interpret the results.**
#
# **b. Calculate mean and 5% confidence interval and plot it in a graph.**
#
# **c. Calculate the Mean absolute deviation and Standard deviation and interpret the results.**
#
# **d. Calculate the correlation coefficient and check the significance of it at 1% level of significance.**

# %%
import pandas as pd
data=pd.read_csv('https://drive.google.com/u/0/uc?id=1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y&export=download')

# %%
data.head()
# Out:
#    Patient ID   Blood Pressure Before (mmHg)   Blood Pressure After (mmHg)
# 0           1                            130                           120
# 1           2                            142                           135
# 2           3                            120                           118
# 3           4                            135                           127
# 4           5                            148                           140

# %%
import seaborn as sns

# %%
data.columns
# Out:
# Index(['Patient ID', ' Blood Pressure Before (mmHg)',
#        ' Blood Pressure After (mmHg)'],
#       dtype='object')

# %%
sns.kdeplot(data=data, x=data[' Blood Pressure Before (mmHg)'])
#There is not a clear Gaussian distribution
# Out:
# <AxesSubplot:xlabel=' Blood Pressure Before (mmHg)', ylabel='Density'>

# %%
sns.kdeplot(data=data, x=" Blood Pressure After (mmHg)")
#There is not a clear Gaussian distribution
# Out:
# <AxesSubplot:xlabel=' Blood Pressure After (mmHg)', ylabel='Density'>

# %%
sns.pairplot(data)

# %%
sns.scatterplot(x=data[" Blood Pressure Before (mmHg)"],y=data[" Blood Pressure After (mmHg)"])
# Out:
# <AxesSubplot:xlabel=' Blood Pressure Before (mmHg)', ylabel=' Blood Pressure After (mmHg)'>

# %% [markdown]
# Inference: There is a strong positive relationship between 'Blood Pressure Before' and 'Blood Pressure After' that can be seen for the pairplots.
